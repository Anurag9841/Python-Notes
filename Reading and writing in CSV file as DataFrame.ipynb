# %%
import pandas as pd

# %%
df=pd.read_csv("F:\\mysql\\py-master\\stock_data.csv")#---> reading from Csv file

# %%
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df=pd.read_csv("F:\\mysql\\py-master\\stock_data.csv",header=None)#---> removes header

# %%
df
# Out:
#          0              1        2      3              4
# 0  tickers            eps  revenue  price         people
# 1    GOOGL          27.82       87    845     larry page
# 2      WMT           4.61      484     65           n.a.
# 3     MSFT             -1       85     64     bill gates
# 4     RIL   not available       50   1023  mukesh ambani
# 5     TATA            5.6       -1   n.a.     ratan tata

# %%
df=pd.read_csv("F:\\mysql\\py-master\\stock_data.csv",names=["Tickers","Eps","Revenue","Price","People"])#---> to add header

# %%
df
# Out:
#    Tickers            Eps  Revenue  Price         People
# 0  tickers            eps  revenue  price         people
# 1    GOOGL          27.82       87    845     larry page
# 2      WMT           4.61      484     65           n.a.
# 3     MSFT             -1       85     64     bill gates
# 4     RIL   not available       50   1023  mukesh ambani
# 5     TATA            5.6       -1   n.a.     ratan tata

# %%
df=pd.read_csv("F:\\mysql\\py-master\\stock_data.csv",na_values=["not available","n.a."])
#---> to replace values in rows by NAN using list

# %%
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3    RIL     NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %%
df=pd.read_csv("F:\\mysql\\py-master\\stock_data.csv",
               na_values={"eps":["not available","n.a."],"revenue":["not available","n.a.",-1],
                                                                "people":["n.a."],"price":["n.a."]})

# %%
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT  -1.00     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
df.to_csv("new.csv",columns=["tickers","eps"],index=False)

# %%
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT  -1.00     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT  -1.00     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
import pandas as pd

# %%
df=pd.read_csv("F:\\mysql\\py-master\\stock_data.csv",na_values={"eps":["not available","n.a."],"revenue":[-1],"price":["n.a."],
                                                                "people":["n.a."]})

# %%
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT  -1.00     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
df.to_csv("stock_data",header=False,index=False)

# %%
df.set_index("tickers",inplace=True)#---setting tickers as index

# %%
df
# Out:
#            eps  revenue   price         people
# tickers
# GOOGL    27.82     87.0   845.0     larry page
# WMT       4.61    484.0    65.0            NaN
# MSFT     -1.00     85.0    64.0     bill gates
# RIL        NaN     50.0  1023.0  mukesh ambani
# TATA      5.60      NaN     NaN     ratan tata

# %%
df
# Out:
#            eps  revenue   price         people
# tickers
# GOOGL    27.82     87.0   845.0     larry page
# WMT       4.61    484.0    65.0            NaN
# MSFT     -1.00     85.0    64.0     bill gates
# RIL        NaN     50.0  1023.0  mukesh ambani
# TATA      5.60      NaN     NaN     ratan tata

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT  -1.00     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata
