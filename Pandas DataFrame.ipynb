# %%
import pandas as pd
import numpy as np

# %%
weather={"day":['2/1/2021','2/2/2021','2/3/2021','2/4/2021','2/5/2021','2/6/2021'],
              "temperature":[24,25,22.5,27,32,35],
             "windspeed":[6,7,4,6,2,4],
             "event":["rainy","windy","snowy","sunny","rainy","foggy"]
             }

# %%
df=pd.DataFrame(weather)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  2/1/2021         24.0          6  rainy
# 1  2/2/2021         25.0          7  windy
# 2  2/3/2021         22.5          4  snowy
# 3  2/4/2021         27.0          6  sunny
# 4  2/5/2021         32.0          2  rainy
# 5  2/6/2021         35.0          4  foggy

# %%
df.head()#--> prints 1st few elements
# Out:
#         day  temperature  windspeed  event
# 0  2/1/2021         24.0          6  rainy
# 1  2/2/2021         25.0          7  windy
# 2  2/3/2021         22.5          4  snowy
# 3  2/4/2021         27.0          6  sunny
# 4  2/5/2021         32.0          2  rainy

# %%
df.tail()#---> prints last few elments
# Out:
#         day  temperature  windspeed  event
# 1  2/2/2021         25.0          7  windy
# 2  2/3/2021         22.5          4  snowy
# 3  2/4/2021         27.0          6  sunny
# 4  2/5/2021         32.0          2  rainy
# 5  2/6/2021         35.0          4  foggy

# %% [markdown]
# Index slicing

# %%
df[1:5]#---> prints data from row 1 st to row 4(ie 5th row is exclued)
# Out:
#         day  temperature  windspeed  event
# 1  2/2/2021         25.0          7  windy
# 2  2/3/2021         22.5          4  snowy
# 3  2/4/2021         27.0          6  sunny
# 4  2/5/2021         32.0          2  rainy

# %%
df[:]#---> prints all data
# Out:
#         day  temperature  windspeed  event
# 0  2/1/2021         24.0          6  rainy
# 1  2/2/2021         25.0          7  windy
# 2  2/3/2021         22.5          4  snowy
# 3  2/4/2021         27.0          6  sunny
# 4  2/5/2021         32.0          2  rainy
# 5  2/6/2021         35.0          4  foggy

# %%
df.columns  #---> gives the columns present in dataframe
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.day #---> gives all the data of day only
# Out:
# 0    2/1/2021
# 1    2/2/2021
# 2    2/3/2021
# 3    2/4/2021
# 4    2/5/2021
# 5    2/6/2021
# Name: day, dtype: object

# %%
df.temperature #---> gives all the data of temperature only
# Out:
# 0    24.0
# 1    25.0
# 2    22.5
# 3    27.0
# 4    32.0
# 5    35.0
# Name: temperature, dtype: float64

# %%
df["temperature"]
# Out:
# 0    24.0
# 1    25.0
# 2    22.5
# 3    27.0
# 4    32.0
# 5    35.0
# Name: temperature, dtype: float64

# %%
df[["event","temperature"]]#---> gives data of event only
# Out:
#    event  temperature
# 0  rainy         24.0
# 1  windy         25.0
# 2  snowy         22.5
# 3  sunny         27.0
# 4  rainy         32.0
# 5  foggy         35.0

# %%
df[["temperature","day"]][df.event=="rainy"]#--> gives data of temp and day when event is rainy
# Out:
#    temperature       day
# 0         24.0  2/1/2021
# 4         32.0  2/5/2021

# %%
df[df.temperature==df["temperature"].max()]#--> returns all data when temperature is maximum
# Out:
#         day  temperature  windspeed  event
# 5  2/6/2021         35.0          4  foggy

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  2/1/2021         24.0          6  rainy
# 1  2/2/2021         25.0          7  windy
# 2  2/3/2021         22.5          4  snowy
# 3  2/4/2021         27.0          6  sunny
# 4  2/5/2021         32.0          2  rainy
# 5  2/6/2021         35.0          4  foggy

# %%
df.loc[0]
# Out:
# day            2/1/2021
# temperature        24.0
# windspeed             6
# event             rainy
# Name: 0, dtype: object

# %%
df.loc[0:2]
# Out:
#         day  temperature  windspeed  event
# 0  2/1/2021         24.0          6  rainy
# 1  2/2/2021         25.0          7  windy
# 2  2/3/2021         22.5          4  snowy

# %%
df[0:2]
# Out:
#         day  temperature  windspeed  event
# 0  2/1/2021         24.0          6  rainy
# 1  2/2/2021         25.0          7  windy

# %%
df.set_index("temperature",inplace=True)

# %%
df
# Out:
#                   day  windspeed  event
# temperature
# 24.0         2/1/2021          6  rainy
# 25.0         2/2/2021          7  windy
# 22.5         2/3/2021          4  snowy
# 27.0         2/4/2021          6  sunny
# 32.0         2/5/2021          2  rainy
# 35.0         2/6/2021          4  foggy

# %%
df.loc[25]
# Out:
# day          2/2/2021
# windspeed           7
# event           windy
# Name: 25.0, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    temperature       day  windspeed  event
# 0         24.0  2/1/2021          6  rainy
# 1         25.0  2/2/2021          7  windy
# 2         22.5  2/3/2021          4  snowy
# 3         27.0  2/4/2021          6  sunny
# 4         32.0  2/5/2021          2  rainy
# 5         35.0  2/6/2021          4  foggy

# %%
df=pd.read_csv("F:\\mysql\\weather.csv")

# %%
df
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes

# %%
df.head()
# Out:
#     outlook temperature humidity  windy play
# 0  overcast         hot     high  False  yes
# 1  overcast        cool   normal   True  yes
# 2  overcast        mild     high   True  yes
# 3  overcast         hot   normal  False  yes
# 4     rainy        mild     high  False  yes

# %%
df.tail()
# Out:
#    outlook temperature humidity  windy play
# 9    sunny         hot     high  False   no
# 10   sunny         hot     high   True   no
# 11   sunny        mild     high  False   no
# 12   sunny        cool   normal  False  yes
# 13   sunny        mild   normal   True  yes

# %%
df[0:10]
# Out:
#     outlook temperature humidity  windy play
# 0  overcast         hot     high  False  yes
# 1  overcast        cool   normal   True  yes
# 2  overcast        mild     high   True  yes
# 3  overcast         hot   normal  False  yes
# 4     rainy        mild     high  False  yes
# 5     rainy        cool   normal  False  yes
# 6     rainy        cool   normal   True   no
# 7     rainy        mild   normal  False  yes
# 8     rainy        mild     high   True   no
# 9     sunny         hot     high  False   no

# %%
df[df.temperature=="hot"]
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 3   overcast         hot   normal  False  yes
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no

# %%
df[["outlook","humidity","windy"]][df.windy==True]
# Out:
#      outlook humidity  windy
# 1   overcast   normal   True
# 2   overcast     high   True
# 6      rainy   normal   True
# 8      rainy     high   True
# 10     sunny     high   True
# 13     sunny   normal   True

# %%
df.set_index("windy",inplace=True)

# %%
df
# Out:
#         outlook temperature humidity play
# windy
# False  overcast         hot     high  yes
# True   overcast        cool   normal  yes
# True   overcast        mild     high  yes
# False  overcast         hot   normal  yes
# False     rainy        mild     high  yes
# False     rainy        cool   normal  yes
# True      rainy        cool   normal   no
# False     rainy        mild   normal  yes
# True      rainy        mild     high   no
# False     sunny         hot     high   no
# True      sunny         hot     high   no
# False     sunny        mild     high   no
# False     sunny        cool   normal  yes
# True      sunny        mild   normal  yes

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     windy   outlook temperature humidity play
# 0   False  overcast         hot     high  yes
# 1    True  overcast        cool   normal  yes
# 2    True  overcast        mild     high  yes
# 3   False  overcast         hot   normal  yes
# 4   False     rainy        mild     high  yes
# 5   False     rainy        cool   normal  yes
# 6    True     rainy        cool   normal   no
# 7   False     rainy        mild   normal  yes
# 8    True     rainy        mild     high   no
# 9   False     sunny         hot     high   no
# 10   True     sunny         hot     high   no
# 11  False     sunny        mild     high   no
# 12  False     sunny        cool   normal  yes
# 13   True     sunny        mild   normal  yes

# %%
df.columns
# Out:
# Index(['windy', 'outlook', 'temperature', 'humidity', 'play'], dtype='object')

# %%
df[["windy","outlook"]]
# Out:
#     windy   outlook
# 0   False  overcast
# 1    True  overcast
# 2    True  overcast
# 3   False  overcast
# 4   False     rainy
# 5   False     rainy
# 6    True     rainy
# 7   False     rainy
# 8    True     rainy
# 9   False     sunny
# 10   True     sunny
# 11  False     sunny
# 12  False     sunny
# 13   True     sunny
